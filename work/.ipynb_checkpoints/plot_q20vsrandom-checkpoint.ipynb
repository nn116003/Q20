# %%
# coding:utf-8
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('acc_qs.csv')

# %%
#plt.plot(data)
plt.figure(figsize=(12, 20), dpi=200)
data.plot()
plt.title('accuracy for each number of questions')
plt.xlabel('number of questions')
plt.ylabel('accuracy')
plt.savefig('q20vsr.png',dpi=200)
